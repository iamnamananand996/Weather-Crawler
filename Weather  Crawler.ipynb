# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select

import bs4
import requests

# %%
def weather(place,date=None,forcast_value=None):
    
    
    if (date is None) and (forcast_value is None):
        forcast_value = 1
    elif forcast_value is None:
        forcast_value = 6
    
    month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    forecast = ['today','hourbyhour','5day','tenday','weekend','monthly']
    result = {}
    print(date,forcast_value)
    time.sleep(3)
    search.send_keys(place)
    print (browser.current_url)
    time.sleep(3)
    search_box = browser.find_element_by_class_name("styles__item__sCSPm")
    
    time.sleep(3)
    search_box.click()
    print(browser.current_url)
    url = browser.current_url
    api_key = url.split('/')[-1]
    
    
    
    url = 'https://weather.com/en-IN/weather/'+forecast[forcast_value-1]+'/l/'+api_key
    
    
    print(url)
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    
    
    
    if forcast_value == 1 or (date is None and  forcast_value is None):
        data = soup.find_all("div","styles__heroFlex__3ulSz")
        dir(data[0])
        result['Location'] = data[0].find_all('h1',"today_nowcard-location")[0].text
        result['Time'] = data[0].find_all('p',"today_nowcard-timestamp")[0].find_all('span')[1].text
        result['Temperature'] = data[0].find_all('div',"today_nowcard-temp")[0].find_all('span')[0].text
        result['Weather'] = data[0].find_all('div',"today_nowcard-phrase")[0].text
        
        for res in data[0].find_all('div',"today_nowcard-sidecar")[0].find_all('table')[0].find_all('tr'):
            result[res.find_all('th')[0].text] = res.find_all('td')[0].text
            
        print(result)
    
    elif forcast_value == 2:
        place = soup.find_all('region','region-main')[0].find_all('div','hourly-page-title')[0].text
        print(place)
        for i in range(len(soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('div','hourly-time'))):
            result['Time'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[1].find_all('div')[0].find_all('div','hourly-time')[0].find_all('span')[0].text
            result['Description'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[2].text
            result['Temp'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[3].text
            result['Feels'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[4].text
            result['Precip'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[5].text
            result['Humidity'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[6].text
            result['Wind'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[7].text

            print(result)
            result = {}
            
    elif forcast_value == 3:
        place = soup.find_all('region','region-main')[0].find_all('div','five-day-page-title')[0].text
        print(place)
        for i in range(0,len(soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr'))):
            day = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[1].find_all('span')[0].text
            date = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[1].find_all('span')[1].text

            result['Day'] = day+' '+date
            result['Description'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[2].text
            result['High/Low'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[3].text
            result['Precip'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[4].text
            result['Wind'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[5].text
            result['Humidity'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[6].text

            print(result)
            result = {}
            
    elif forcast_value == 4:
        place = soup.find_all('region','region-main')[0].find_all('div','ten-day-page-title')[0].text
        print(place)
        for i in range(0,len(soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr'))):
            day = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[1].find_all('span')[0].text
            date = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[1].find_all('span')[1].text

            result['Day'] = day+' '+date
            result['Description'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[2].text
            result['High/Low'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[3].text
            result['Precip'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[4].text
            result['Wind'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[5].text
            result['Humidity'] = soup.find_all('region','region-main')[0].find_all('table','twc-table')[0].find_all('tbody')[0].find_all('tr')[i].find_all('td')[6].text

            print(result)
            result = {}

    elif forcast_value == 6 or date is not None:
        print(date)
        if date is not None:
            browser.get(url)
#             print('comes here')
            drop_down = browser.find_element_by_id("month-picker")
            drop_down.click()
            time.sleep(1)
            drop_down = Select(drop_down)
            
            date = date.split('/')

            time.sleep(3)
            drop_down.select_by_visible_text(month[int(date[1])-1]+' '+date[2])
            month[int(date[1])-1]+' '+date[2]
        
            place = soup.find_all('region','region-main')[0].find_all('div','monthly-page-title')[0].text
            print(place)
            for i in range(len(soup.find_all('div','dayCell'))):
                if soup.find_all('div','dayCell')[i].find_all('div','date')[0].text == date[0]:
                    result['Temp_high'] = soup.find_all('div','dayCell')[i].find_all('div','temp')[0].find_all('span')[0].text
                    result['Temp_low'] = soup.find_all('div','dayCell')[i].find_all('div','temp')[1].find_all('span')[0].text

                    print(result)
                    result = {}
        else:
            place = soup.find_all('region','region-main')[0].find_all('div','monthly-page-title')[0].text
            print(place)
            for i in range(len(soup.find_all('div','dayCell'))):
                result['Date'] = soup.find_all('div','dayCell')[i].find_all('div','date')[0].text
                result['Temp_high'] = soup.find_all('div','dayCell')[i].find_all('div','temp')[0].find_all('span')[0].text
                result['Temp_low'] = soup.find_all('div','dayCell')[i].find_all('div','temp')[1].find_all('span')[0].text

                print(result)
                result = {}

# %%
forecast = ['today','hourbyhour','5day','tenday','weekend','monthly']


browser = webdriver.Chrome("chromedriver.exe")
browser.get("https://weather.com/en-IN/")



while True:
    search = browser.find_element_by_class_name("theme__inputElement__4bZUj")
    place = input('Enter the city name : (Enter q to exit) ')
    
    
    if place == 'q':
        break
    date = input('Enter Date in DD/MM/YYYY : ')
    print(' 1. Today\n 2. Hour By Hour\n 3. 5 Day\n 4. 10 Day\n 5. Weekend\n 6. Monthly')
    forecast = input('Enter the Choice :')
    
    if forecast == '' and date == '':
        weather(place)
    elif forecast == '':
        weather(place,date)
    elif date == '':
        weather(place,forcast_value=int(forecast))
    else:
        weather(place,date,int(forecast))
# Out:
# Enter the city name : (Enter q to exit) banaglore
# Enter Date in DD/MM/YYYY : 12/3/2020
#  1. Today
#  2. Hour By Hour
#  3. 5 Day
#  4. 10 Day
#  5. Weekend
#  6. Monthly
# Enter the Choice :6
# 12/3/2020 6
# https://weather.com/en-IN/
# https://weather.com/en-IN/weather/today/l/e5e5d9e304a310cd9f5387b75551e92f5e8cab07d343b649a100e4096931e227
# https://weather.com/en-IN/weather/monthly/l/e5e5d9e304a310cd9f5387b75551e92f5e8cab07d343b649a100e4096931e227
# 12/3/2020
# Bangalore, Karnataka Monthly Weather21:10 IST
# {'Temp_high': '28°', 'Temp_low': '21°'}
# Enter the city name : (Enter q to exit) bangalore
# Enter Date in DD/MM/YYYY :
#  1. Today
#  2. Hour By Hour
#  3. 5 Day
#  4. 10 Day
#  5. Weekend
#  6. Monthly
# Enter the Choice :
# None 1
# https://weather.com/en-IN/weather/monthly/l/e5e5d9e304a310cd9f5387b75551e92f5e8cab07d343b649a100e4096931e227
# https://weather.com/en-IN/weather/monthly/l/e5e5d9e304a310cd9f5387b75551e92f5e8cab07d343b649a100e4096931e227
# ...
